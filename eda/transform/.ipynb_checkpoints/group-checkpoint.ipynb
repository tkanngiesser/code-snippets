# %% [markdown]
# # Transform and Visualise Example: Tidyverse compared to Python (Pandas, Seaborn, Altair)

# %% [markdown]
# **Remark:** not much effort has been spent on tweaking the charts, focus is to show how
# transformation and visualisation could be done in Python compared to the tidyverse approach

# %%
# %matplotlib inline
from IPython.display import Image

# %%
import pandas as pd
import seaborn as sns
sns.set_style('white')
import altair as alt

# %% [markdown]
# #### Import data

# %%
users = pd.read_csv('/Users/tinokanngiesser/code/vfu_eda/data/users.csv')

# %% [markdown]
# #### Transform and Visualise with R

# %% [raw]
# users %>%
#   select(user_market, user_id) %>%
#   group_by(user_market) %>%
#   summarise(
#     count = n()
#   ) %>%
#   ggplot(aes(x=user_market, y=count)) +
#   geom_bar(stat="identity", color="blue", fill="blue") +
#   theme_minimal() +
#   theme(axis.text.x=element_text(angle=90,hjust=1,vjust=0.5))

# %%
Image(filename='/Users/tinokanngiesser/code/vfu_eda/data/plot.png')

# %% [markdown]
# #### Transformation Step in Python

# %%
experiment_01[['user_market','count']] = (users[['user_market', 'user_id']] 
 .groupby(['user_market']) 
 .agg(['count']) 
 .reset_index()           
)

# %% [markdown]
# #### Visualise with Python Pandas

# %%
ax = experiment_01.plot.bar()
ax.set_xlabel("x label")
ax.set_ylabel("y label")
# Out:
# Text(0,0.5,'y label')

# %%
(users[['user_market', 'user_id']] #select
 .groupby(['user_market']) #group by
 .agg(['count'])
 .plot.bar()); #aggregate = summarise

# %% [markdown]
# #### Transform and Visualise with Python Seaborn

# %%
ax = sns.barplot(x='user_market', y='count', data=experiment_01)
ax.set_xticklabels(labels=experiment_01['user_market'], rotation=90);

# %% [markdown]
# #### Transform and Visualise with Python Altair

# %%
alt.Chart(experiment_01).mark_bar().encode(
    x='user_market',
    y='count'
)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html
